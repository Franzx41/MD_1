# %%
import pandas as pd
import numpy as np
import seaborn as sns
pd.set_option('display.max_columns', 200)

# %%
data = pd.read_csv("data/merged_data.csv")
data.head()
# Out:
#     hero_names Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black     NaN
#
#            Publisher Skin color Alignment  Weight  Agility  \
# 0      Marvel Comics        NaN      good   441.0    False
# 1  Dark Horse Comics       blue      good    65.0     True
# 2          DC Comics        red      good    90.0    False
# 3      Marvel Comics        NaN       bad   441.0    False
# 4      Marvel Comics        NaN       bad     NaN    False
#
#    Accelerated Healing  Lantern Power Ring  Dimensional Awareness  \
# 0                 True               False                  False
# ...

# %%
from sklearn.metrics import matthews_corrcoef

# %%
binary_data  = data.select_dtypes(include='bool')
poderes_corr = binary_data.corr(method=matthews_corrcoef)

# %%
poderes_corr
# Out:
#                         Agility  Accelerated Healing  Lantern Power Ring  \
# Agility                1.000000             0.273917            0.023233
# Accelerated Healing    0.273917             1.000000           -0.025514
# Lantern Power Ring     0.023233            -0.025514            1.000000
# Dimensional Awareness  0.029517             0.126953           -0.024901
# Cold Resistance        0.106084             0.149922           -0.035514
# Durability             0.146989             0.252934           -0.007379
# Stealth                0.392190             0.103257           -0.063397
# Energy Absorption      0.043826             0.157333           -0.046528
# Flight                -0.015370             0.139452            0.136468
# Danger Sense           0.244567             0.254471           -0.029240
# Underwater breathing   0.026249             0.032486            0.105101
# Marksmanship           0.342438             0.109702            0.149117
# ...

# %%
#parece que não ha diferença entre pandas corr pearson e phi coeficient
#no pdf das medidas de distancia em binario o phi coeficiente ta lá com o nome de pearson&heronI
#será que o pandas é tão barril que muda a formula dependendo do tipo de entrada
#achei agora no google, esse metodo gera o Pearson's rho, que no modo binario retorna o phi
binary_data.corr()
# Out:
#                         Agility  Accelerated Healing  Lantern Power Ring  \
# Agility                1.000000             0.273917            0.023233
# Accelerated Healing    0.273917             1.000000           -0.025514
# Lantern Power Ring     0.023233            -0.025514            1.000000
# Dimensional Awareness  0.029517             0.126953           -0.024901
# Cold Resistance        0.106084             0.149922           -0.035514
# Durability             0.146989             0.252934           -0.007379
# Stealth                0.392190             0.103257           -0.063397
# Energy Absorption      0.043826             0.157333           -0.046528
# Flight                -0.015370             0.139452            0.136468
# Danger Sense           0.244567             0.254471           -0.029240
# Underwater breathing   0.026249             0.032486            0.105101
# Marksmanship           0.342438             0.109702            0.149117
# ...

# %%
binary_data_test = binary_data[['Agility', 'Accelerated Healing', 'Lantern Power Ring', 'Dimensional Awareness', 'Cold Resistance']].head()
binary_data_test
# Out:
#    Agility  Accelerated Healing  Lantern Power Ring  Dimensional Awareness  \
# 0    False                 True               False                  False
# 1     True                 True               False                  False
# 2    False                False                True                  False
# 3    False                 True               False                  False
# 4    False                False               False                   True
#
#    Cold Resistance
# 0            False
# 1             True
# 2            False
# 3            False
# 4            False

# %% [markdown]
# Agility 	1.000000 	0.408248 	-0.250000 	-0.250000 	1.000000
# Accelerated Healing 	0.408248 	1.000000 	-0.612372 	-0.612372 	0.408248
# Lantern Power Ring 	-0.250000 	-0.612372 	1.000000 	-0.250000 	-0.250000
# Dimensional Awareness 	-0.250000 	-0.612372 	-0.250000 	1.000000 	-0.250000
# Cold Resistance 	1.000000 	0.408248 	-0.250000 	-0.250000 	1.000000

# %%
binary_data_test.corr(method=matthews_corrcoef)
# Out:
#                         Agility  Accelerated Healing  Lantern Power Ring  \
# Agility                1.000000             0.408248           -0.250000
# Accelerated Healing    0.408248             1.000000           -0.612372
# Lantern Power Ring    -0.250000            -0.612372            1.000000
# Dimensional Awareness -0.250000            -0.612372           -0.250000
# Cold Resistance        1.000000             0.408248           -0.250000
#
#                        Dimensional Awareness  Cold Resistance
# Agility                            -0.250000         1.000000
# Accelerated Healing                -0.612372         0.408248
# Lantern Power Ring                 -0.250000        -0.250000
# Dimensional Awareness               1.000000        -0.250000
# Cold Resistance                    -0.250000         1.000000

# %%
sns.heatmap(poderes_corr)
